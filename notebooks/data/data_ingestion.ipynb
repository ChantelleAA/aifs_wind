# %% [markdown]
# [ROOT]/[yyyymmdd]/[HH]z/[model]/[resol]/[stream]/[yyyymmdd][HH]0000-[step][U]-[stream]-[type].[format]

# %%
# %pip install ecmwf-opendata
# Out:
# Requirement already satisfied: ecmwf-opendata in /home/chantelle/miniconda3/envs/aifs_env/lib/python3.11/site-packages (0.3.26)
# Requirement already satisfied: multiurl>=0.2.1 in /home/chantelle/miniconda3/envs/aifs_env/lib/python3.11/site-packages (from ecmwf-opendata) (0.3.7)
# Requirement already satisfied: requests in /home/chantelle/miniconda3/envs/aifs_env/lib/python3.11/site-packages (from multiurl>=0.2.1->ecmwf-opendata) (2.32.5)
# Requirement already satisfied: tqdm in /home/chantelle/miniconda3/envs/aifs_env/lib/python3.11/site-packages (from multiurl>=0.2.1->ecmwf-opendata) (4.67.1)
# Requirement already satisfied: pytz in /home/chantelle/miniconda3/envs/aifs_env/lib/python3.11/site-packages (from multiurl>=0.2.1->ecmwf-opendata) (2025.2)
# Requirement already satisfied: python-dateutil in /home/chantelle/miniconda3/envs/aifs_env/lib/python3.11/site-packages (from multiurl>=0.2.1->ecmwf-opendata) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/chantelle/miniconda3/envs/aifs_env/lib/python3.11/site-packages (from python-dateutil->multiurl>=0.2.1->ecmwf-opendata) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/chantelle/miniconda3/envs/aifs_env/lib/python3.11/site-packages (from requests->multiurl>=0.2.1->ecmwf-opendata) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/chantelle/miniconda3/envs/aifs_env/lib/python3.11/site-packages (from requests->multiurl>=0.2.1->ecmwf-opendata) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/chantelle/miniconda3/envs/aifs_env/lib/python3.11/site-packages (from requests->multiurl>=0.2.1->ecmwf-opendata) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chantelle/miniconda3/envs/aifs_env/lib/python3.11/site-packages (from requests->multiurl>=0.2.1->ecmwf-opendata) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ECMWF runs its model four times every day, at 00z, 06z, 12z, and 18z (z means UTC). Each run takes the current state of the atmosphere as its starting point — this starting point is called the analysis — and then projects forward in time, producing forecast fields at regular intervals called steps.

# %%
a = list(range(0, 144, 3)) + list(range(144, 241, 6))
a
# Out:
# [0,
#  3,
#  6,
#  9,
#  12,
#  15,
#  18,
#  21,
#  24,
#  27,
#  30,
#  33,
#  36,
#  39,
#  42,
#  45,
#  48,
#  51,
#  54,
#  57,
#  60,
#  63,
#  66,
#  69,
#  72,
#  75,
#  78,
#  81,
#  84,
#  87,
#  90,
#  93,
#  96,
#  99,
#  102,
#  105,
#  108,
#  111,
#  114,
#  117,
#  120,
#  123,
#  126,
#  129,
#  132,
#  135,
#  138,
#  141,
#  144,
#  150,
#  156,
#  162,
#  168,
#  174,
#  180,
#  186,
#  192,
#  198,
#  204,
#  210,
#  216,
#  222,
#  228,
#  234,
#  240]
